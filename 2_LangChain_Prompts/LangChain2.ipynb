# %% [markdown]
# # PROMTS in LangChain

# %% [markdown]
# -->A prompt for a language model is a set of instructions or input provided by a user to guide the model's response, helping it understand the context and generate relevant and coherent language-based output, such as answering questions, completing sentences, or engaging in a conversation.

# %% [markdown]
# ![Screenshot%202025-04-04%20at%2012.47.36%E2%80%AFPM.png](attachment:Screenshot%202025-04-04%20at%2012.47.36%E2%80%AFPM.png)

# %% [markdown]
# --->types:
#
# -Text-based Prompts : Text as an input
#
# -Multi-Models Prompts : along with text something suchas image,video,audio,pdf,documents as an input
