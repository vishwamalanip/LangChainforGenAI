# %% [markdown]
# # Langchain Models

# %% [markdown]
# Models ---> Language Models --->LLMS      --->Open-source      -->hugging-face
#
#                                           --->Closed-source    -->Gemini(Google)
#
#                                                                -->GPT(OpenAI)
#
#                                                                -->Claude(Anthropic)
#
#                             --->chatbots
#
#        ---> Embedding Models--->RAG based  (worked on given pdf or documents)
#
#                                           --->Open-source      -->hugging-face
#
#                                           --->Closed-source    -->GPT(OpenAI)

# %% [markdown]
# ![Screenshot%202025-04-03%20at%2010.33.15%E2%80%AFAM.png](attachment:Screenshot%202025-04-03%20at%2010.33.15%E2%80%AFAM.png)

# %% [markdown]
# ![Screenshot%202025-04-03%20at%2010.37.41%E2%80%AFAM.png](attachment:Screenshot%202025-04-03%20at%2010.37.41%E2%80%AFAM.png)

# %% [markdown]
# 4th step. for Mac users( source venv/bin/activate )

# %% [markdown]
# ![Screenshot%202025-04-03%20at%2012.49.49%E2%80%AFPM.png](attachment:Screenshot%202025-04-03%20at%2012.49.49%E2%80%AFPM.png)

# %% [markdown]
#     --->Open-source Models

# %% [markdown]
# ![Screenshot%202025-04-03%20at%207.33.32%E2%80%AFPM.png](attachment:Screenshot%202025-04-03%20at%207.33.32%E2%80%AFPM.png)

# %% [markdown]
# ![Screenshot%202025-04-03%20at%207.36.18%E2%80%AFPM.png](attachment:Screenshot%202025-04-03%20at%207.36.18%E2%80%AFPM.png)

# %% [markdown]
# ![Screenshot%202025-04-03%20at%207.40.27%E2%80%AFPM.png](attachment:Screenshot%202025-04-03%20at%207.40.27%E2%80%AFPM.png)

# %% [markdown]
# ![Screenshot%202025-04-03%20at%207.42.17%E2%80%AFPM.png](attachment:Screenshot%202025-04-03%20at%207.42.17%E2%80%AFPM.png)
